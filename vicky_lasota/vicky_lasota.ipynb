# %%
# Dependencies
import os
import pathlib
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from uszipcode import SearchEngine


# Import the API key
from config import geoapify_key

# %%
# URL for GET requests to retrieve brewery data
base_url = 'https://api.openbrewerydb.org/v1/breweries?by_country=United_States'

#example of the url for the first page
#https://api.openbrewerydb.org/v1/breweries?by_country=United_States&page=1&per_page=200
#query_url = base_url + "&page="+ page + "&per_page=200"

# Define an empty list to fetch the page data for each set of data
brewery_data = []

# Loop through the pages to get all the data
for page in range(1, 156):
    query_url = base_url + "&page="+ str(page) + "&per_page=200"
    response = requests.get(query_url).json()
    brewery_data.append(response)

# Create a list of all the breweries
breweries = []
for page in brewery_data:
    for brewery in page:
        breweries.append(brewery)

# Create a dataframe from the list of breweries
breweries_df = pd.DataFrame(breweries)

breweries_df.head()
# Out:
#                                      id                  name brewery_type  \
# 0  5128df48-79fc-4f0f-8b52-d06be54d0cec      (405) Brewing Co        micro
# 1  9c5a66c8-cc13-416f-a5d9-0a769c87d318      (512) Brewing Co        micro
# 2  ef970757-fe42-416f-931d-722451f1f59c  10 Barrel Brewing Co        large
# 3  6d14b220-8926-4521-8d19-b98a2d6ec3db  10 Barrel Brewing Co        large
# 4  e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2  10 Barrel Brewing Co        large
#
#                      address_1 address_2 address_3       city state_province  \
# 0               1716 Topeka St      None      None     Norman       Oklahoma
# 1        407 Radam Ln Ste F200      None      None     Austin          Texas
# 2                    1501 E St      None      None  San Diego     California
# 3                62970 18th St      None      None       Bend         Oregon
# 4  1135 NW Galveston Ave Ste B      None      None       Bend         Oregon
#
#   postal_code        country     longitude     latitude       phone  \
# 0  73069-8224  United States  -97.46818222  35.25738891  4058160490
# 1  78745-1197  United States          None         None  5129211545
# 2  92101-6618  United States   -117.129593    32.714813  6195782311
# 3  97701-9847  United States   -121.281706  44.08683531  5415851007
# 4  97703-2465  United States  -121.3288021   44.0575649  5415851007
#
#                  website_url       state                       street
# 0  http://www.405brewing.com    Oklahoma               1716 Topeka St
# 1  http://www.512brewing.com       Texas        407 Radam Ln Ste F200
# 2        http://10barrel.com  California                    1501 E St
# 3    http://www.10barrel.com      Oregon                62970 18th St
# 4                       None      Oregon  1135 NW Galveston Ave Ste B

# %%
# Pretty print JSON for all launchpads

#response = requests.get(query_url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#create a dataframe from the json response
#breweries_df = pd.DataFrame(response)
#breweries_df.head(4)

# %%
#creates a summary table of the data
breweries_df.describe()
# Out:
#                                           id                         name  \
# count                                   7936                         7936
# unique                                  7936                         7791
# top     5128df48-79fc-4f0f-8b52-d06be54d0cec  Granite City Food & Brewery
# freq                                       1                            6
#
#        brewery_type    address_1 address_2 address_3      city state_province  \
# count          7936         7153         4         0      7936           7936
# unique           10         7064         4         0      2908             54
# top           micro  303 Main St  Estacada       NaN  Portland     California
# freq           4115            3         1       NaN       105            912
#
#        postal_code        country     longitude    latitude       phone  \
# count         7936           7936          5544        5544        7141
# unique        7695              2          5433        5433        6950
# top          64108  United States  -112.0773456  33.4485866  5122442739
# freq             5           7935             6           6           5
#
#                 website_url       state       street
# count                  6787        7936         7153
# unique                 6437          54         7064
# top     http://www.gcfb.net  California  303 Main St
# freq                     23         912            3

# %%
#Prepare the breweries Database for analysis 
#drop brevery id, address_2, address_3, country, phone, website_url, and street
clean_breweries_df = breweries_df.drop(columns=['id', 'address_2', 'address_3', 'country', 'phone', 'website_url', 'street'])
clean_breweries_df.head()
# Out:
#                    name brewery_type                    address_1       city  \
# 0      (405) Brewing Co        micro               1716 Topeka St     Norman
# 1      (512) Brewing Co        micro        407 Radam Ln Ste F200     Austin
# 2  10 Barrel Brewing Co        large                    1501 E St  San Diego
# 3  10 Barrel Brewing Co        large                62970 18th St       Bend
# 4  10 Barrel Brewing Co        large  1135 NW Galveston Ave Ste B       Bend
#
#   state_province postal_code     longitude     latitude       state
# 0       Oklahoma  73069-8224  -97.46818222  35.25738891    Oklahoma
# 1          Texas  78745-1197          None         None       Texas
# 2     California  92101-6618   -117.129593    32.714813  California
# 3         Oregon  97701-9847   -121.281706  44.08683531      Oregon
# 4         Oregon  97703-2465  -121.3288021   44.0575649      Oregon

# %%
#count missing values for each column
clean_breweries_df.isnull()
#count missing values for each column 
clean_breweries_df.isnull().sum()

# TEAM: We need to decide how to handle the missing values.  Do we drop the rows?
# Out:
# name                 0
# brewery_type         0
# address_1          783
# city                 0
# state_province       0
# postal_code          0
# longitude         2392
# latitude          2392
# state                0
# dtype: int64

# %%
#create a new column in dataframe with first 5 digits of zip code - geopify doesn't look up +4

search = SearchEngine()

def extract_zipcode(zipcode):
    # Remove +4 extension if present
    zipcode = zipcode.split('-')[0]
    zipcode_obj = search.by_zipcode(zipcode)
    if zipcode_obj is not None:
        return str(zipcode_obj.zipcode)[:5].zfill(5)
    else:
        return None

clean_breweries_df['zip_code'] = clean_breweries_df['postal_code'].apply(extract_zipcode).astype(str)

#add a ditinct ID number to each row 
clean_breweries_df['brewery_id'] = clean_breweries_df.index + 1
clean_breweries_df.head()
# Out:
#                    name brewery_type                    address_1       city  \
# 0      (405) Brewing Co        micro               1716 Topeka St     Norman
# 1      (512) Brewing Co        micro        407 Radam Ln Ste F200     Austin
# 2  10 Barrel Brewing Co        large                    1501 E St  San Diego
# 3  10 Barrel Brewing Co        large                62970 18th St       Bend
# 4  10 Barrel Brewing Co        large  1135 NW Galveston Ave Ste B       Bend
#
#   state_province postal_code     longitude     latitude       state zip_code  \
# 0       Oklahoma  73069-8224  -97.46818222  35.25738891    Oklahoma    73069
# 1          Texas  78745-1197          None         None       Texas    78745
# 2     California  92101-6618   -117.129593    32.714813  California    92101
# 3         Oregon  97701-9847   -121.281706  44.08683531      Oregon    97701
# 4         Oregon  97703-2465  -121.3288021   44.0575649      Oregon    97703
#
#    brewery_id
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
#load dataframe into csv
clean_breweries_df.to_csv('breweries.csv', index=False)
#show count by the length of the postal code to see if there are any invalid postal codes
clean_breweries_df['zip_code'].str.len().value_counts()
# Out:
# 5    7929
# 4       7
# Name: zip_code, dtype: int64

# %%
#use dataframe from the csv breveries.csv
input_path = os.path.join("breweries.csv")
csv_breweries_df = pd.read_csv(input_path)

# %%
#postcode = "78745"
#target_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={postcode}&limit=1&type=postcode&format=json&apiKey={geoapify_key}"
#response = requests.get(target_url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#exctract rows with missing longitude and create a new dataframe
missing_long_df = csv_breweries_df[csv_breweries_df['longitude'].isnull()]
missing_long_df.head()
# Out:
#                         name brewery_type                  address_1  \
# 1           (512) Brewing Co        micro      407 Radam Ln Ste F200
# 18  12 Gates Brewing Company      brewpub       80 Earhart Dr Ste 20
# 19   12 West Brewing Company        micro       3000 E Ray Rd Bldg 6
# 24      12welve Eyes Brewing        micro       141 E 4th St Ste LL2
# 26        13 Stripes Brewery      brewpub  250 Mill St, Suite PW3101
#
#              city  state_province postal_code  longitude  latitude  \
# 1          Austin           Texas  78745-1197        NaN       NaN
# 18  Williamsville        New York  14221-7804        NaN       NaN
# 19        Gilbert         Arizona  85296-7832        NaN       NaN
# 24     Saint Paul       Minnesota  55101-1639        NaN       NaN
# 26        Taylors  South Carolina       29687        NaN       NaN
#
#              state zip_code  brewery_id
# 1            Texas    78745           2
# 18        New York    14221          19
# 19         Arizona    85296          20
# 24       Minnesota    55101          25
# 26  South Carolina    29687          27

# %%
#for missing longitude, use geopify to look up the longitude and latitude
for index, row in missing_long_df.iterrows():
        postcode = row['zip_code']
        target_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={postcode}&limit=1&type=postcode&format=json&apiKey={geoapify_key}"
        response = requests.get(target_url).json()
#try:
        missing_long_df.loc[index, 'longitude'] = response['results'][0]['lon']
        missing_long_df.loc[index, 'latitude'] = response['results'][0]['lat']
        print(f"brewery_id: {index}, postcode: {postcode}, longitude: {response['results'][0]['lon']}, latitude: {response['results'][0]['lat']}") 
#except IndexError as e:
        #print(f"index: {index}, postcode: {postcode}, error: {e}")
        #pass

         
missing_long_df.head()
# Out:
# brewery_id: 1, postcode: 78745, longitude: -97.792614846, latitude: 30.208605656
# brewery_id: 18, postcode: 14221, longitude: -78.729920877, latitude: 42.980952841
# brewery_id: 19, postcode: 85296, longitude: -111.762518433, latitude: 33.335136701
# brewery_id: 24, postcode: 55101, longitude: -93.088300242, latitude: 44.955919207
# brewery_id: 26, postcode: 29687, longitude: -82.327800669, latitude: 34.991467109
# brewery_id: 28, postcode: 27603, longitude: -78.66089377, latitude: 35.71301003
# brewery_id: 30, postcode: 56442, longitude: -94.116315338, latitude: 46.677860236
# brewery_id: 32, postcode: 05478, longitude: -73.104390267, latitude: 44.803484605
# brewery_id: 36, postcode: 21157, longitude: -76.983937143, latitude: 39.558197671
# brewery_id: 39, postcode: 22553, longitude: -77.60125509, latitude: 38.231176411
# brewery_id: 49, postcode: 11741, longitude: -73.070358674, latitude: 40.794962148
# brewery_id: 50, postcode: 05452, longitude: -73.08637315, latitude: 44.51595767
# brewery_id: 55, postcode: 20109, longitude: -77.506105128, latitude: 38.784153209
# brewery_id: 62, postcode: 13750, longitude: -74.82975865, latitude: 42.474391832
# brewery_id: 67, postcode: 41653, longitude: -82.767732377, latitude: 37.665449029
# brewery_id: 68, postcode: 99021, longitude: -117.369133938, latitude: 47.765802869
# brewery_id: 71, postcode: 77095, longitude: -95.652018308, latitude: 29.898842698
# brewery_id: 75, postcode: 19106, longitude: -75.14627831, latitude: 39.950672901
# brewery_id: 76, postcode: 19014, longitude: -75.563552437, latitude: 39.887258814
# brewery_id: 86, postcode: 97321, longitude: -123.111273467, latitude: 44.609191436
# brewery_id: 88, postcode: 20012, longitude: -77.025561983, latitude: 38.970399774
# brewery_id: 90, postcode: 06475, longitude: -72.385634332, latitude: 41.288536478
# brewery_id: 91, postcode: 80501, longitude: -105.106413721, latitude: 40.170633272
# brewery_id: 95, postcode: 80122, longitude: -104.979683709, latitude: 39.584167995
# brewery_id: 96, postcode: 59634, longitude: -111.969697748, latitude: 46.530167633
# brewery_id: 101, postcode: 32578, longitude: -86.43102344, latitude: 30.489422954
# brewery_id: 104, postcode: 19940, longitude: -75.550673024, latitude: 38.476202655
# brewery_id: 107, postcode: 80021, longitude: -105.086665676, latitude: 39.885154083
# brewery_id: 109, postcode: 30518, longitude: -84.042062612, latitude: 34.100259626
# brewery_id: 110, postcode: 59715, longitude: -111.050200127, latitude: 45.685106985
# brewery_id: 112, postcode: 15136, longitude: -80.079481383, latitude: 40.473635621
# brewery_id: 115, postcode: 47203, longitude: -85.859714314, latitude: 39.221491124
# brewery_id: 120, postcode: 77055, longitude: -95.49586778, latitude: 29.795283748
# brewery_id: 125, postcode: 32607, longitude: -82.407912692, latitude: 29.644031328
# brewery_id: 131, postcode: 30318, longitude: -84.445715822, latitude: 33.788472774
# brewery_id: 140, postcode: 55418, longitude: -93.243478973, latitude: 45.020879789
# brewery_id: 142, postcode: 78641, longitude: -97.893362346, latitude: 30.544304067
# brewery_id: 144, postcode: 78572, longitude: -98.326435596, latitude: 26.216903062
# brewery_id: 146, postcode: 22406, longitude: -77.549292213, latitude: 38.392371502
# brewery_id: 147, postcode: 30097, longitude: -84.157329898, latitude: 34.028487173
# brewery_id: 149, postcode: 03053, longitude: -71.380217881, latitude: 42.867839412
# brewery_id: 150, postcode: 54603, longitude: -91.248383303, latitude: 43.846908132
# brewery_id: 154, postcode: 81631, longitude: -106.827995669, latitude: 39.656721042
# brewery_id: 156, postcode: 20852, longitude: -77.120222912, latitude: 39.05014409
# brewery_id: 157, postcode: 08242, longitude: -74.879574555, latitude: 39.018524212
# brewery_id: 164, postcode: 02052, longitude: -71.320668951, latitude: 42.19822306
# brewery_id: 165, postcode: 34698, longitude: -82.770051007, latitude: 28.026017129
# brewery_id: 166, postcode: 59538, longitude: -107.871968567, latitude: 48.355487183
# brewery_id: 168, postcode: 85323, longitude: -112.321577408, latitude: 33.426515001
# brewery_id: 169, postcode: 33611, longitude: -82.503229675, latitude: 27.890585682
# brewery_id: 173, postcode: 12603, longitude: -73.882828376, latitude: 41.679079582
# brewery_id: 178, postcode: 60081, longitude: -88.217267191, latitude: 42.440759553
# brewery_id: 180, postcode: 32514, longitude: -87.206440843, latitude: 30.523541086
# brewery_id: 182, postcode: 14527, longitude: -77.05634915, latitude: 42.654847171
# brewery_id: 183, postcode: 01027, longitude: -72.734012711, latitude: 42.302961856
# brewery_id: 189, postcode: 70433, longitude: -90.103775527, latitude: 30.464246476
# brewery_id: 190, postcode: 15136, longitude: -80.079481383, latitude: 40.473635621
# brewery_id: 191, postcode: 89104, longitude: -115.124572354, latitude: 36.152481072
# brewery_id: 194, postcode: 49312, longitude: -85.830222014, latitude: 43.687785329
# brewery_id: 212, postcode: 20132, longitude: -77.714000834, latitude: 39.151948009
# brewery_id: 213, postcode: 22405, longitude: -77.433204156, latitude: 38.318948098
# brewery_id: 214, postcode: 22408, longitude: -77.464656909, latitude: 38.244819678
# brewery_id: 220, postcode: 40217, longitude: -85.739452677, latitude: 38.217515932
# brewery_id: 223, postcode: 54868, longitude: -91.72754486, latitude: 45.512118629
# brewery_id: 225, postcode: 54201, longitude: -87.463142834, latitude: 44.611658567
# brewery_id: 232, postcode: 40206, longitude: -85.701082293, latitude: 38.257439611
# brewery_id: 234, postcode: 13655, longitude: -74.658795225, latitude: 44.978597312
# brewery_id: 239, postcode: 60646, longitude: -87.764710279, latitude: 41.999866774
# brewery_id: 244, postcode: 37882, longitude: -83.778038213, latitude: 35.689814935
# brewery_id: 246, postcode: 78582, longitude: -98.770074191, latitude: 26.385887464
# brewery_id: 247, postcode: 05676, longitude: -72.759069942, latitude: 44.328812091
# brewery_id: 252, postcode: 87008, longitude: -106.37057375, latitude: 35.121608586
# brewery_id: 253, postcode: 98292, longitude: -122.325600203, latitude: 48.231850468
# brewery_id: 256, postcode: 45424, longitude: -84.122408876, latitude: 39.846273834
# brewery_id: 261, postcode: 23188, longitude: -76.761680768, latitude: 37.317684106
# brewery_id: 263, postcode: 41001, longitude: -84.394667598, latitude: 38.940416004
# brewery_id: 265, postcode: 87110, longitude: -106.590515353, latitude: 35.099392778
# brewery_id: 268, postcode: 15601, longitude: -79.534038105, latitude: 40.298406166
# brewery_id: 288, postcode: 10009, longitude: -73.980779861, latitude: 40.72586124
# brewery_id: 291, postcode: 80218, longitude: -104.971877055, latitude: 39.731240864
# brewery_id: 295, postcode: 60515, longitude: -88.015536014, latitude: 41.809420343
# brewery_id: 298, postcode: 78666, longitude: -97.952473296, latitude: 29.868931182
# brewery_id: 299, postcode: 01518, longitude: -72.115974653, latitude: 42.118869642
# brewery_id: 303, postcode: 06051, longitude: -72.770321247, latitude: 41.666424749
# brewery_id: 305, postcode: 80221, longitude: -105.019873859, latitude: 39.788257898
# brewery_id: 311, postcode: 48216, longitude: -83.074393746, latitude: 42.328045413
# brewery_id: 313, postcode: 98020, longitude: -122.369890525, latitude: 47.803115004
# brewery_id: 318, postcode: 33328, longitude: -80.277369012, latitude: 26.06696354
# brewery_id: 328, postcode: 02764, longitude: -71.142693167, latitude: 41.86334305
# brewery_id: 332, postcode: 32092, longitude: -81.505742105, latitude: 29.96915847
# brewery_id: 333, postcode: 10913, longitude: -73.960757646, latitude: 41.064088537
# brewery_id: 335, postcode: 04849, longitude: -69.033007394, latitude: 44.331322061
# brewery_id: 338, postcode: 75904, longitude: -94.754244721, latitude: 31.337770324
# brewery_id: 340, postcode: 07848, longitude: -74.694218032, latitude: 41.091190336
# brewery_id: 341, postcode: 29072, longitude: -81.253315181, latitude: 33.991346773
# brewery_id: 348, postcode: 28621, longitude: -80.838301401, latitude: 36.287267925
# brewery_id: 353, postcode: 30121, longitude: -84.78974395, latitude: 34.210738608
# brewery_id: 359, postcode: 07114, longitude: -74.174481036, latitude: 40.714809044
# brewery_id: 362, postcode: 34112, longitude: -81.748436305, latitude: 26.122256932
# brewery_id: 364, postcode: 21740, longitude: -77.733536694, latitude: 39.63372226
# brewery_id: 366, postcode: 75686, longitude: -94.970203672, latitude: 32.992289991
# brewery_id: 368, postcode: 10917, longitude: -74.123809851, latitude: 41.325964511
# brewery_id: 371, postcode: 19426, longitude: -75.450480416, latitude: 40.176992404
# brewery_id: 372, postcode: 17325, longitude: -77.218238338, latitude: 39.829491551
# brewery_id: 375, postcode: 17050, longitude: -77.000214339, latitude: 40.250839863
# brewery_id: 381, postcode: 78666, longitude: -97.952473296, latitude: 29.868931182
# brewery_id: 382, postcode: 02540, longitude: -70.608401758, latitude: 41.568372093
# brewery_id: 384, postcode: 78336, longitude: -97.156848857, latitude: 27.91367968
# brewery_id: 385, postcode: 55418, longitude: -93.243478973, latitude: 45.020879789
# brewery_id: 393, postcode: 30354, longitude: -84.393050457, latitude: 33.665921023
# brewery_id: 394, postcode: 28806, longitude: -82.608628461, latitude: 35.581634989
# brewery_id: 396, postcode: 01007, longitude: -72.412311684, latitude: 42.28385679
# brewery_id: 398, postcode: 62234, longitude: -89.987654699, latitude: 38.680167358
# brewery_id: 399, postcode: 19711, longitude: -75.742365514, latitude: 39.69890302
# brewery_id: 402, postcode: 85611, longitude: -110.546317007, latitude: 31.615534686
# brewery_id: 403, postcode: 85233, longitude: -111.812372051, latitude: 33.360091533
# brewery_id: 404, postcode: 33771, longitude: -82.757249211, latitude: 27.916416159
# brewery_id: 417, postcode: 08226, longitude: -74.592597504, latitude: 39.266403697
# brewery_id: 419, postcode: 12866, longitude: -73.768392155, latitude: 43.076557618
# brewery_id: 427, postcode: 80301, longitude: -105.19820583, latitude: 40.049959087
# brewery_id: 433, postcode: 20170, longitude: -77.380850487, latitude: 38.982202428
# brewery_id: 436, postcode: 28031, longitude: -80.88043646, latitude: 35.468551668
# brewery_id: 438, postcode: 19014, longitude: -75.563552437, latitude: 39.887258814
# brewery_id: 440, postcode: 77018, longitude: -95.424184626, latitude: 29.825242492
# brewery_id: 441, postcode: 20910, longitude: -77.030087458, latitude: 38.999837101
# brewery_id: 442, postcode: 89011, longitude: -114.979937738, latitude: 36.076504249
# brewery_id: 448, postcode: 06615, longitude: -73.135212324, latitude: 41.177934697
# brewery_id: 449, postcode: 32233, longitude: -81.408054662, latitude: 30.337437821
# brewery_id: 450, postcode: 04609, longitude: -68.260751753, latitude: 44.374190167
# brewery_id: 453, postcode: 20002, longitude: -76.989463089, latitude: 38.903656992
# brewery_id: 456, postcode: 80908, longitude: -104.694610356, latitude: 38.959744651
# brewery_id: 457, postcode: 21701, longitude: -77.376801764, latitude: 39.437743707
# brewery_id: 458, postcode: 19144, longitude: -75.172051294, latitude: 40.034289496
# brewery_id: 465, postcode: 46706, longitude: -85.052835351, latitude: 41.327411871
# brewery_id: 468, postcode: 56073, longitude: -94.465584473, latitude: 44.311735285
# brewery_id: 472, postcode: 13081, longitude: -76.633591496, latitude: 42.662069655
# brewery_id: 473, postcode: 12944, longitude: -73.476581329, latitude: 44.49346418
# brewery_id: 476, postcode: 04103, longitude: -70.288034627, latitude: 43.690366679
# brewery_id: 483, postcode: 08028, longitude: -75.1072552, latitude: 39.712855338
# brewery_id: 487, postcode: 20141, longitude: -77.778003303, latitude: 39.134940762
# brewery_id: 488, postcode: 77304, longitude: -95.500849608, latitude: 30.33241993
# brewery_id: 489, postcode: 77803, longitude: -96.3741074, latitude: 30.680152507
# brewery_id: 490, postcode: 21031, longitude: -76.659310827, latitude: 39.485838896
# brewery_id: 492, postcode: 10018, longitude: -73.990394122, latitude: 40.75412645
# brewery_id: 493, postcode: 77423, longitude: -95.958800689, latitude: 29.799519856
# brewery_id: 494, postcode: 98604, longitude: -122.54509131, latitude: 45.782599461
# brewery_id: 500, postcode: 21401, longitude: -76.518245918, latitude: 38.983826354
# brewery_id: 501, postcode: 06002, longitude: -72.727245559, latitude: 41.833110523
# brewery_id: 504, postcode: 77365, longitude: -95.257051556, latitude: 30.105277461
# brewery_id: 508, postcode: 05161, longitude: -72.791592251, latitude: 43.294342233
# brewery_id: 510, postcode: 02215, longitude: -71.102231062, latitude: 42.348071873
# brewery_id: 511, postcode: 08889, longitude: -74.760550221, latitude: 40.602953156
# brewery_id: 514, postcode: 22645, longitude: -78.248669206, latitude: 39.028597863
# brewery_id: 515, postcode: 21842, longitude: -75.074538931, latitude: 38.381922824
# brewery_id: 517, postcode: 59912, longitude: -114.185411403, latitude: 48.375051972
# brewery_id: 520, postcode: 75482, longitude: -95.600738146, latitude: 33.128916548
# brewery_id: 522, postcode: 08731, longitude: -74.177157175, latitude: 39.833682246
# brewery_id: 525, postcode: 34785, longitude: -82.031629276, latitude: 28.842843067
# brewery_id: 527, postcode: 89011, longitude: -114.979937738, latitude: 36.076504249
# brewery_id: 530, postcode: 46928, longitude: -85.637314246, latitude: 40.409958904
# brewery_id: 531, postcode: 56374, longitude: -94.315347009, latitude: 45.576489491
# brewery_id: 532, postcode: 37174, longitude: -86.896754588, latitude: 35.743959477
# brewery_id: 542, postcode: 55379, longitude: -93.495585305, latitude: 44.779407662
# brewery_id: 546, postcode: 20110, longitude: -77.475756085, latitude: 38.756789968
# brewery_id: 548, postcode: 80203, longitude: -104.983315967, latitude: 39.730809092
# brewery_id: 551, postcode: 04947, longitude: -70.262186107, latitude: 45.044177378
# brewery_id: 556, postcode: 44870, longitude: -82.71029758, latitude: 41.436161366
# brewery_id: 559, postcode: 55122, longitude: -93.194122232, latitude: 44.801789675
# brewery_id: 569, postcode: 60607, longitude: -87.652333102, latitude: 41.877401094
# brewery_id: 574, postcode: 21222, longitude: -76.50251519, latitude: 39.264547375
# brewery_id: 578, postcode: 04005, longitude: -70.462385263, latitude: 43.482444207
# brewery_id: 580, postcode: 78003, longitude: -99.064201378, latitude: 29.726655217
# brewery_id: 581, postcode: 59840, longitude: -114.146363562, latitude: 46.235739641
# brewery_id: 584, postcode: 55114, longitude: -93.195754872, latitude: 44.964963851
# brewery_id: 586, postcode: 89101, longitude: -115.138884638, latitude: 36.167317991
# brewery_id: 587, postcode: 33069, longitude: -80.156449021, latitude: 26.233460177
# brewery_id: 588, postcode: 04401, longitude: -68.802317056, latitude: 44.821079336
# brewery_id: 589, postcode: 18013, longitude: -75.189187972, latitude: 40.860387095
# brewery_id: 590, postcode: 25840, longitude: -81.10367556, latitude: 38.048982614
# brewery_id: 600, postcode: 64063, longitude: -94.356180212, latitude: 38.912408471
# brewery_id: 606, postcode: 46530, longitude: -86.149473585, latitude: 41.741049285
# brewery_id: 613, postcode: 28227, longitude: -80.676246709, latitude: 35.190376074
# brewery_id: 615, postcode: 68144, longitude: -96.125457923, latitude: 41.234621132
# brewery_id: 620, postcode: 06355, longitude: -71.985087595, latitude: 41.365749524
# brewery_id: 621, postcode: 46060, longitude: -85.976017468, latitude: 40.036383254
# brewery_id: 623, postcode: 54017, longitude: -92.526623795, latitude: 45.122079266
# brewery_id: 624, postcode: 22554, longitude: -77.408716353, latitude: 38.444390539
# brewery_id: 627, postcode: 89014, longitude: -115.048054273, latitude: 36.062095502
# brewery_id: 635, postcode: 80134, longitude: -104.763157187, latitude: 39.497117559
# brewery_id: 636, postcode: 20176, longitude: -77.51703899, latitude: 39.102399165
# brewery_id: 639, postcode: 86338, longitude: -112.687856, latitude: 34.488892
# brewery_id: 640, postcode: 11735, longitude: -73.443287983, latitude: 40.7254134
# brewery_id: 643, postcode: 78751, longitude: -97.723825961, latitude: 30.310431088
# brewery_id: 649, postcode: 02189, longitude: -70.926274029, latitude: 42.204815908
# brewery_id: 651, postcode: 20144, longitude: -77.931479969, latitude: 38.910307512
# brewery_id: 652, postcode: 33487, longitude: -80.08764181, latitude: 26.408038233
# brewery_id: 657, postcode: 11572, longitude: -73.638303312, latitude: 40.635481502
# brewery_id: 658, postcode: 01230, longitude: -73.358075888, latitude: 42.199212811
# brewery_id: 667, postcode: 23224, longitude: -77.47225526, latitude: 37.495958194
# brewery_id: 670, postcode: 33613, longitude: -82.447110177, latitude: 28.072299596
# brewery_id: 674, postcode: 78723, longitude: -97.691987337, latitude: 30.301328648
# brewery_id: 678, postcode: 04103, longitude: -70.288034627, latitude: 43.690366679
# brewery_id: 679, postcode: 89501, longitude: -119.813665182, latitude: 39.525005622
# brewery_id: 682, postcode: 17325, longitude: -77.218238338, latitude: 39.829491551
# brewery_id: 683, postcode: 22407, longitude: -77.548581781, latitude: 38.262408318
# brewery_id: 684, postcode: 77494, longitude: -95.798367365, latitude: 29.746501837
# brewery_id: 691, postcode: 33130, longitude: -80.205261567, latitude: 25.767955507
# brewery_id: 694, postcode: 01566, longitude: -72.088318362, latitude: 42.116253619
# brewery_id: 696, postcode: 15206, longitude: -79.917612654, latitude: 40.469104728
# brewery_id: 697, postcode: 70512, longitude: -91.942864404, latitude: 30.415833034
# brewery_id: 698, postcode: 60542, longitude: -88.331899439, latitude: 41.807899241
# brewery_id: 704, postcode: 32937, longitude: -80.597843182, latitude: 28.169939405
# brewery_id: 709, postcode: 38104, longitude: -90.001566072, latitude: 35.131543524
# brewery_id: 711, postcode: 01027, longitude: -72.734012711, latitude: 42.302961856
# brewery_id: 712, postcode: 04009, longitude: -70.734447997, latitude: 44.057891401
# brewery_id: 714, postcode: 20135, longitude: -77.865713851, latitude: 39.105161815
# brewery_id: 715, postcode: 27207, longitude: -79.390483848, latitude: 35.611841114
# brewery_id: 723, postcode: 77377, longitude: -95.650548619, latitude: 30.031337683
# brewery_id: 725, postcode: 61602, longitude: -89.595364263, latitude: 40.689185209
# brewery_id: 734, postcode: 59353, longitude: -104.190437643, latitude: 46.982761243
# brewery_id: 736, postcode: 86001, longitude: -111.65652457, latitude: 35.19631999
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 7
#       5         response = requests.get(target_url).json()
#       6 #try:
# ----> 7         missing_long_df.loc[index, 'longitude'] = response['results'][0]['lon']
#       8         missing_long_df.loc[index, 'latitude'] = response['results'][0]['lat']
#       9         print(f"brewery_id: {index}, postcode: {postcode}, longitude: {response['results'][0]['lon']}, latitude: {response['results'][0]['lat']}")
#
# IndexError: list index out of range
