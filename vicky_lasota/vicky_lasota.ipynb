# %%
# Dependencies
import os
import pathlib
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# Import the API key
from config import geoapify_key

# %%
# URL for GET requests to retrieve brewery data
base_url = 'https://api.openbrewerydb.org/v1/breweries?by_country=United_States'

#example of the url for the first page
#https://api.openbrewerydb.org/v1/breweries?by_country=United_States&page=1&per_page=200
#query_url = base_url + "&page="+ page + "&per_page=200"

# Define an empty list to fetch the page data for each set of data
brewery_data = []

# Loop through the pages to get all the data
for page in range(1, 156):
    query_url = base_url + "&page="+ str(page) + "&per_page=200"
    response = requests.get(query_url).json()
    brewery_data.append(response)

# Create a list of all the breweries
breweries = []
for page in brewery_data:
    for brewery in page:
        breweries.append(brewery)

# Create a dataframe from the list of breweries
breweries_df = pd.DataFrame(breweries)

breweries_df.head()
# Out:
#                                      id                  name brewery_type  \
# 0  5128df48-79fc-4f0f-8b52-d06be54d0cec      (405) Brewing Co        micro
# 1  9c5a66c8-cc13-416f-a5d9-0a769c87d318      (512) Brewing Co        micro
# 2  ef970757-fe42-416f-931d-722451f1f59c  10 Barrel Brewing Co        large
# 3  6d14b220-8926-4521-8d19-b98a2d6ec3db  10 Barrel Brewing Co        large
# 4  e2e78bd8-80ff-4a61-a65c-3bfbd9d76ce2  10 Barrel Brewing Co        large
#
#                      address_1 address_2 address_3       city state_province  \
# 0               1716 Topeka St      None      None     Norman       Oklahoma
# 1        407 Radam Ln Ste F200      None      None     Austin          Texas
# 2                    1501 E St      None      None  San Diego     California
# 3                62970 18th St      None      None       Bend         Oregon
# 4  1135 NW Galveston Ave Ste B      None      None       Bend         Oregon
#
#   postal_code        country     longitude     latitude       phone  \
# 0  73069-8224  United States  -97.46818222  35.25738891  4058160490
# 1  78745-1197  United States          None         None  5129211545
# 2  92101-6618  United States   -117.129593    32.714813  6195782311
# 3  97701-9847  United States   -121.281706  44.08683531  5415851007
# 4  97703-2465  United States  -121.3288021   44.0575649  5415851007
#
#                  website_url       state                       street
# 0  http://www.405brewing.com    Oklahoma               1716 Topeka St
# 1  http://www.512brewing.com       Texas        407 Radam Ln Ste F200
# 2        http://10barrel.com  California                    1501 E St
# 3    http://www.10barrel.com      Oregon                62970 18th St
# 4                       None      Oregon  1135 NW Galveston Ave Ste B

# %%
# Pretty print JSON for all launchpads

#response = requests.get(query_url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#create a dataframe from the json response
#breweries_df = pd.DataFrame(response)
#breweries_df.head(4)

# %%
#creates a summary table of the data
breweries_df.describe()
# Out:
#                                           id                         name  \
# count                                   7936                         7936
# unique                                  7936                         7791
# top     5128df48-79fc-4f0f-8b52-d06be54d0cec  Granite City Food & Brewery
# freq                                       1                            6
#
#        brewery_type    address_1 address_2 address_3      city state_province  \
# count          7936         7153         4         0      7936           7936
# unique           10         7064         4         0      2908             54
# top           micro  303 Main St  Estacada       NaN  Portland     California
# freq           4115            3         1       NaN       105            912
#
#        postal_code        country     longitude    latitude       phone  \
# count         7936           7936          5544        5544        7141
# unique        7695              2          5433        5433        6950
# top          64108  United States  -112.0773456  33.4485866  5122442739
# freq             5           7935             6           6           5
#
#                 website_url       state       street
# count                  6787        7936         7153
# unique                 6437          54         7064
# top     http://www.gcfb.net  California  303 Main St
# freq                     23         912            3

# %%
#Prepare the breweries Database for analysis 
#drop brevery id, address_2, address_3, country, phone, website_url, and street
clean_breweries_df = breweries_df.drop(columns=['id', 'address_2', 'address_3', 'country', 'phone', 'website_url', 'street'])
clean_breweries_df.head()
# Out:
#                    name brewery_type                    address_1       city  \
# 0      (405) Brewing Co        micro               1716 Topeka St     Norman
# 1      (512) Brewing Co        micro        407 Radam Ln Ste F200     Austin
# 2  10 Barrel Brewing Co        large                    1501 E St  San Diego
# 3  10 Barrel Brewing Co        large                62970 18th St       Bend
# 4  10 Barrel Brewing Co        large  1135 NW Galveston Ave Ste B       Bend
#
#   state_province postal_code     longitude     latitude       state
# 0       Oklahoma  73069-8224  -97.46818222  35.25738891    Oklahoma
# 1          Texas  78745-1197          None         None       Texas
# 2     California  92101-6618   -117.129593    32.714813  California
# 3         Oregon  97701-9847   -121.281706  44.08683531      Oregon
# 4         Oregon  97703-2465  -121.3288021   44.0575649      Oregon

# %%
#count missing values for each column
clean_breweries_df.isnull()
#count missing values for each column 
clean_breweries_df.isnull().sum()

# TEAM: We need to decide how to handle the missing values.  Do we drop the rows?
# Out:
# name                 0
# brewery_type         0
# address_1          783
# city                 0
# state_province       0
# postal_code          0
# longitude         2392
# latitude          2392
# state                0
# dtype: int64

# %%
#create a new column in dataframe with first 5 digits of zip code - geopify doesn't look up +4
clean_breweries_df['zip_code'] = clean_breweries_df['postal_code'].str[:5]
clean_breweries_df.head()
# Out:
#                    name brewery_type                    address_1       city  \
# 0      (405) Brewing Co        micro               1716 Topeka St     Norman
# 1      (512) Brewing Co        micro        407 Radam Ln Ste F200     Austin
# 2  10 Barrel Brewing Co        large                    1501 E St  San Diego
# 3  10 Barrel Brewing Co        large                62970 18th St       Bend
# 4  10 Barrel Brewing Co        large  1135 NW Galveston Ave Ste B       Bend
#
#   state_province postal_code     longitude     latitude       state zip_code
# 0       Oklahoma  73069-8224  -97.46818222  35.25738891    Oklahoma    73069
# 1          Texas  78745-1197          None         None       Texas    78745
# 2     California  92101-6618   -117.129593    32.714813  California    92101
# 3         Oregon  97701-9847   -121.281706  44.08683531      Oregon    97701
# 4         Oregon  97703-2465  -121.3288021   44.0575649      Oregon    97703

# %%
#load dataframe into csv
clean_breweries_df.to_csv('breweries.csv', index=False)
#show count by the length of the postal code to see if there are any invalid postal codes
clean_breweries_df['zip_code'].str.len().value_counts()
# Out:
# 5    7936
# Name: zip_code, dtype: int64

# %%
#use dataframe from the csv breveries.csv
input_path = os.path.join("breweries.csv")
csv_breweries_df = pd.read_csv(input_path)

# %%
#postcode = "78745"
#target_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={postcode}&limit=1&type=postcode&format=json&apiKey={geoapify_key}"
#response = requests.get(target_url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
#exctract rows with missing longitude and create a new dataframe
missing_long_df = csv_breweries_df[csv_breweries_df['longitude'].isnull()]
missing_long_df.head()
# Out:
#                         name brewery_type                  address_1  \
# 1           (512) Brewing Co        micro      407 Radam Ln Ste F200
# 18  12 Gates Brewing Company      brewpub       80 Earhart Dr Ste 20
# 19   12 West Brewing Company        micro       3000 E Ray Rd Bldg 6
# 24      12welve Eyes Brewing        micro       141 E 4th St Ste LL2
# 26        13 Stripes Brewery      brewpub  250 Mill St, Suite PW3101
#
#              city  state_province postal_code  longitude  latitude  \
# 1          Austin           Texas  78745-1197        NaN       NaN
# 18  Williamsville        New York  14221-7804        NaN       NaN
# 19        Gilbert         Arizona  85296-7832        NaN       NaN
# 24     Saint Paul       Minnesota  55101-1639        NaN       NaN
# 26        Taylors  South Carolina       29687        NaN       NaN
#
#              state  zip_code
# 1            Texas     78745
# 18        New York     14221
# 19         Arizona     85296
# 24       Minnesota     55101
# 26  South Carolina     29687

# %%
#if longitude and latitude null then use the value from respective zip_code to get the longitude from the api
#store the longitude in the dataframe
for index, row in missing_long_df.iterrows():
                if pd.isnull(row['longitude']) and pd.isnull(row['latitude']):
                        postcode = row['zip_code']
                        target_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={postcode}&limit=1&type=postcode&format=json&apiKey={geoapify_key}"
                        response = requests.get(target_url).json()
                        missing_long_df.loc[index, 'longitude'] = response['results'][0]['lon']
                        missing_long_df.loc[index, 'latitude'] = response['results'][0]['lat']
                        print(f"index: {index}, postcode: {postcode}, longitude: {response['results'][0]['lon']}, latitude: {response['results'][0]['lat']}")
                        
missing_long_df.head()
# Out:
# index: 1, postcode: 78745, longitude: -97.792614846, latitude: 30.208605656
# index: 18, postcode: 14221, longitude: -78.729920877, latitude: 42.980952841
# index: 19, postcode: 85296, longitude: -111.762518433, latitude: 33.335136701
# index: 24, postcode: 55101, longitude: -93.088300242, latitude: 44.955919207
# index: 26, postcode: 29687, longitude: -82.327800669, latitude: 34.991467109
# index: 28, postcode: 27603, longitude: -78.66089377, latitude: 35.71301003
# index: 30, postcode: 56442, longitude: -94.116315338, latitude: 46.677860236
# index: 32, postcode: 5478, longitude: -68.67620435, latitude: -31.547226
# index: 36, postcode: 21157, longitude: -76.983937143, latitude: 39.558197671
# index: 39, postcode: 22553, longitude: -77.60125509, latitude: 38.231176411
# index: 49, postcode: 11741, longitude: -73.070358674, latitude: 40.794962148
# index: 50, postcode: 5452, longitude: -88.922086084, latitude: 45.542678653
# index: 55, postcode: 20109, longitude: -77.506105128, latitude: 38.784153209
# index: 62, postcode: 13750, longitude: -74.82975865, latitude: 42.474391832
# index: 67, postcode: 41653, longitude: -82.767732377, latitude: 37.665449029
# index: 68, postcode: 99021, longitude: -117.369133938, latitude: 47.765802869
# index: 71, postcode: 77095, longitude: -95.652018308, latitude: 29.898842698
# index: 75, postcode: 19106, longitude: -75.14627831, latitude: 39.950672901
# index: 76, postcode: 19014, longitude: -75.563552437, latitude: 39.887258814
# index: 86, postcode: 97321, longitude: -123.111273467, latitude: 44.609191436
# index: 88, postcode: 20012, longitude: -77.025561983, latitude: 38.970399774
# index: 90, postcode: 6475, longitude: -94.5812001, latitude: 38.13241145
# index: 91, postcode: 80501, longitude: -105.106413721, latitude: 40.170633272
# index: 95, postcode: 80122, longitude: -104.979683709, latitude: 39.584167995
# index: 96, postcode: 59634, longitude: -111.969697748, latitude: 46.530167633
# index: 101, postcode: 32578, longitude: -86.43102344, latitude: 30.489422954
# index: 104, postcode: 19940, longitude: -75.550673024, latitude: 38.476202655
# index: 402, postcode: 85611, longitude: -110.546317007, latitude: 31.615534686
# index: 403, postcode: 85233, longitude: -111.812372051, latitude: 33.360091533
# index: 404, postcode: 33771, longitude: -82.757249211, latitude: 27.916416159
# index: 417, postcode: 8226, longitude: 8.485730104, latitude: 47.748531039
# index: 419, postcode: 12866, longitude: -73.768392155, latitude: 43.076557618
# index: 427, postcode: 80301, longitude: -105.19820583, latitude: 40.049959087
# index: 433, postcode: 20170, longitude: -77.380850487, latitude: 38.982202428
# index: 436, postcode: 28031, longitude: -80.88043646, latitude: 35.468551668
# index: 438, postcode: 19014, longitude: -75.563552437, latitude: 39.887258814
# index: 440, postcode: 77018, longitude: -95.424184626, latitude: 29.825242492
# index: 441, postcode: 20910, longitude: -77.030087458, latitude: 38.999837101
# index: 442, postcode: 89011, longitude: -114.979937738, latitude: 36.076504249
# index: 448, postcode: 6615, longitude: -89.468625, latitude: 40.834986
# index: 449, postcode: 32233, longitude: -81.408054662, latitude: 30.337437821
# index: 450, postcode: 4609, longitude: -86.1616801, latitude: 40.4911541
# index: 453, postcode: 20002, longitude: -76.989463089, latitude: 38.903656992
# index: 456, postcode: 80908, longitude: -104.694610356, latitude: 38.959744651
# index: 457, postcode: 21701, longitude: -77.376801764, latitude: 39.437743707
# index: 458, postcode: 19144, longitude: -75.172051294, latitude: 40.034289496
# index: 465, postcode: 46706, longitude: -85.052835351, latitude: 41.327411871
# index: 468, postcode: 56073, longitude: -94.465584473, latitude: 44.311735285
# index: 472, postcode: 13081, longitude: -76.633591496, latitude: 42.662069655
# index: 473, postcode: 12944, longitude: -73.476581329, latitude: 44.49346418
# index: 476, postcode: 4103, longitude: -84.608680804, latitude: 38.785322607
# index: 483, postcode: 8028, longitude: 32.4445323, latitude: 34.77618325
# index: 487, postcode: 20141, longitude: -77.778003303, latitude: 39.134940762
# index: 488, postcode: 77304, longitude: -95.500849608, latitude: 30.33241993
# index: 489, postcode: 77803, longitude: -96.3741074, latitude: 30.680152507
# index: 490, postcode: 21031, longitude: -76.659310827, latitude: 39.485838896
# index: 492, postcode: 10018, longitude: -73.990394122, latitude: 40.75412645
# index: 493, postcode: 77423, longitude: -95.958800689, latitude: 29.799519856
# index: 494, postcode: 98604, longitude: -122.54509131, latitude: 45.782599461
# index: 500, postcode: 21401, longitude: -76.518245918, latitude: 38.983826354
# index: 501, postcode: 6002, longitude: -88.181575604, latitude: 42.408346994
# index: 504, postcode: 77365, longitude: -95.257051556, latitude: 30.105277461
# index: 508, postcode: 5161, longitude: 13.06274403, latitude: 47.866319916
# index: 510, postcode: 2215, longitude: -77.185075781, latitude: 38.779409921
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[202], line 8
#       6 target_url = f"https://api.geoapify.com/v1/geocode/autocomplete?text={postcode}&limit=1&type=postcode&format=json&apiKey={geoapify_key}"
#       7 response = requests.get(target_url).json()
# ----> 8 missing_long_df.loc[index, 'longitude'] = response['results'][0]['lon']
#       9 missing_long_df.loc[index, 'latitude'] = response['results'][0]['lat']
#      10 print(f"index: {index}, postcode: {postcode}, longitude: {response['results'][0]['lon']}, latitude: {response['results'][0]['lat']}")
#
# IndexError: list index out of range
